# %% [markdown]
# ---
# title: Night At The Museum Peer Grading
# comments: true
# hide: true
# layout: post
# description: Grade 3 Other Teams Not In Class
# courses: { labnb: {week: 12} }
# type: hacks
# ---

# %% [markdown]
# # First Team: Car Rentals
#
# - Group Members
#     - Aditya R
#     - Sai T
#     - Timo Al-Faraje
#     - Sri Tanav Kambhampati
#     - Aditya D
#
# Group Idea: Car rentals that display different cars and their prices(mainly luxury cars)
#
# - Frontend
# - Backend
# - API
# - Agile
#
# HOOK:
# Points: 3.6-4.0
# Didn't spend time talking a lot which was good. Went straight into functionality of the search bar and even let me interact with the website.
#
# KNOWLEDGE:
# Points: 3.6-4.0
# Reason:
# Showed use of API and connection between backend and frontend.
#
# VALUE:
# Points: 0.6-1.0
# Reason:
# I don't think many people are rich enough to buy the luxury cars let alone rent them but if I was a millionare I would look at this website to find the right car for me.
#
# WOW FACTOR:
# Reason:
# The 360 Viewer was really car. Its like a simulation where you get to view other cars and see them close up in detail.
#
# 8.85/10 - The navigation bars are inconsistent. They look good but they are all different

# %% [markdown]
# # Second Team: Pokemon Game
#
# - Group Members
#     - Ashwin V
#     - Ronit T
#     - Vance R
#     - Jared B
#
# - Group Idea: Pokemon game that lets the user move arond to catch pokeballs. Can even increase difficulty by pressing 'M' and the pokeballs will move. Has a search bar where you look up pokemons and the information about them and a quiz to test your pokemon knowledge.
#
# HOOK:
# Points: 3.6-4.0
# Little talking and went straight into playing the game. Even let me play it myself.
#
# KNOWLEDGE:
# Points: 3.6-4.0
# Reason:
# Shows use of backend and API with the pokemon database where you can search for pokemon.
#
# VALUE:
# Points: 0.6-1.0
# Reason:
# Its a fun game that lets you explore your interest in pokemon. Use everyday? No. Fun? Yes.
#
# WOW FACTOR:
# Reason:
# Im surprised they even got movement and sound in a game. I really like the background adventure music and sound effects when getting pokeballs.
#
# 8.8/10 - I wish the game had levels. There was a house and a doorway and I thought if I caught enough pokeballs I could go to the next level.

# %% [markdown]
# # Third Team: Movie Finder
#
# - Group Members
#     - Dante A
#     - Jordan P
#     - Jake S
#     - Ethan R
#
# - Group Idea: You are able to input criteria of a movie you want to find and the finder will give results of movie that fit your criteria.
#
# HOOK:
# Points: 3.6-4.0
# It wasn't that much of a hook. The demonstration and visuals look bland but the idea is cool.
#
# KNOWLEDGE:
# Points: 3.6-4.0
# Reason:
# There is a clear API and database that stores the movies and the call to find the movies that fit the criteria.
#
# VALUE:
# Points: 0.6-1.0
# Reason:
# If I'm bored and want to find a movie to look for, I can easily find it if I want to.
#
# WOW FACTOR:
# Reason:
# I like that there is a wide range of results of movies that display. It isn't even the popular moves too, there are a bunch of underground movies that I've never heard of.
#
# 8.8/10 - There are a bit of bugs like the movie rating criteria doesn't work. Maybe add a "Top Movies this Month/Year".
