# %% [markdown]
# ---
# title: Skincare Ingredients
# comments: true
# hide: true
# layout: post
# description: These are the skincare ingredients in popular Korean skincare products.
# type: ccc
# permalink: /skincare/ingredients
# ---

# %% [raw]
# {% include nav_ingredients.html %}

# %% [raw]
# <link rel="stylesheet" href="/student/assets/css/skincare-ingredients.css">
#
# <body>
#
#     <div>
#         <h1>Skincare Ingredients</h1>
#         <p>Many commerical skincare products are not actually good and contain harsh ingredients. Be sure to check the
#             ingredients in your products before buying them.</p>
#         <p id="message">Click the button!</p>
#         <button class="ingredient-button" id="ingredientSwitcher">Ingredient Switcher</button>
#         <br>
#         <br>
#     </div>
#
#     <div>
#         <a target="blank" href="https://incidecoder.com/" class="ingredient-button" id="inci">INCIDecoder</a>
#         <a target="blank" href="https://www.ewg.org/skindeep/" class="ingredient-button" id="ewg">EWG</a>
#         <p></p>
#     </div>
#
#     <div style="height: 600px">
#
#         <div class="skincare-gallery">
#             <a href="{{site.baseurl}}/skincare/products">
#                 <img src="/student/images/snail-mucin.jpeg" alt="Skincare Products" width="600" height="400">
#             </a>
#             <div class="skincare-desc">
#                 <div>Snail Mucin Essence<br><a href="https://incidecoder.com/ingredients/snail-secretion-filtrate"
#                         title="If you are into the K-Beauty trend, you must have bumped into snail slime like a thousand times..."
#                         target="_blank">Snail Secretion Filtrate</a>, <a
#                         href="https://incidecoder.com/ingredients/betaine"
#                         title="A sugar beet derived amino acid derivative with nice skin protection and moisturization properties. Its special thing is being an osmolyte, a molecule that helps to control cell-water balance. "
#                         target="_blank">Betaine</a>, <a href="https://incidecoder.com/ingredients/butylene-glycol"
#                         title="An often used glycol that works as a solvent, humectant, penetration enhancer and also gives a good slip to the products. "
#                         target="_blank">Butylene Glycol</a>, <a
#                         href="https://incidecoder.com/ingredients/1-2-hexanediol"
#                         title="A multi-functional helper ingredient that acts as a humectant and emollient. It&#39;s also a solvent and can boost the effectiveness of preservatives."
#                         target="_blank">1,2-Hexanediol</a>, <a
#                         href="https://incidecoder.com/ingredients/sodium-hyaluronate"
#                         title="It&#39;s the salt form of famous humectant and natural moisturizing factor, hyaluronic acid. It can bind huge amounts of water and it&#39;s pretty much the current IT-moisturizer."
#                         target="_blank">Sodium Hyaluronate</a>, <a href="https://incidecoder.com/ingredients/panthenol"
#                         title="Pro-Vitamin B5 is a goodie that moisturises the skin, has anti-inflammatory, skin protecting and wound healing properties. "
#                         target="_blank">Panthenol</a>, <a href="https://incidecoder.com/ingredients/arginine"
#                         title="An amino acid that is one of the primary building blocks of hair keratin and skin collagen. It&#39;s a natural moisturizing factor and might also help to speed up wound healing. "
#                         target="_blank">Arginine</a>, <a href="https://incidecoder.com/ingredients/allantoin"
#                         title="Super common soothing ingredient..." target="_blank">Allantoin</a>, <a
#                         href="https://incidecoder.com/ingredients/ethyl-hexanediol"
#                         title="A colorless, slightly viscous liquid that, similar to other glycols, is used as a solvent in cosmetic products..."
#                         target="_blank">Ethyl Hexanediol</a>, <a
#                         href="https://incidecoder.com/ingredients/sodium-polyacrylate"
#                         title="A big polymer (a molecule from repeated subunits) with crazy water binding abilities. Used as a thickening and emulsion stabilizing agent. "
#                         target="_blank">Sodium Polyacrylate</a>, <a href="https://incidecoder.com/ingredients/carbomer"
#                         title="A handy white powder that magically converts a liquid into a nice gel formula."
#                         target="_blank">Carbomer</a>, <a href="https://incidecoder.com/ingredients/phenoxyethanol"
#                         title="Pretty much the current IT-preservative. It’s safe and gentle, and can be used up to 1% worldwide."
#                         target="_blank">Phenoxyethanol</a></div><span style="display:block;"><small>Hover the mouse over
#                         an ingredient for short explanation. Read more on <a
#                             href="https://incidecoder.com/products/cosrx-advanced-snail-96-mucin-power-essence"
#                             target="_blank">INCIDecoder</a>.</small></span>
#             </div>
#         </div>
#
#         <div class="skincare-gallery">
#             <a href="{{site.baseurl}}/skincare/ingredients">
#                 <img src="/student/images/anua-heartleaf.jpeg" alt="Skincare Ingredients" width="600" height="400">
#             </a>
#             <div class="skincare-desc">Anua Heartleaf Toner<div><a
#                         href="https://incidecoder.com/ingredients/houttuynia-cordata-extract"
#                         title="A flavonoid-rich plant extract known mainly for its soothing and antioxidant properties. "
#                         target="_blank">Houttuynia Cordata Extract (77%)</a>, <a
#                         href="https://incidecoder.com/ingredients/water"
#                         title="Normal (well kind of - it&#39;s purified and deionized) water. Usually the main solvent in cosmetic products. "
#                         target="_blank">Water</a>, <a href="https://incidecoder.com/ingredients/1-2-hexanediol"
#                         title="A multi-functional helper ingredient that acts as a humectant and emollient. It&#39;s also a solvent and can boost the effectiveness of preservatives."
#                         target="_blank">1,2-Hexanediol</a>, <a href="https://incidecoder.com/ingredients/glycerin"
#                         title="A real oldie but a goodie. Great natural moisturizer and skin-identical ingredient that plays an important role in skin hydration and general skin health."
#                         target="_blank">Glycerin</a>, <a href="https://incidecoder.com/ingredients/betaine"
#                         title="A sugar beet derived amino acid derivative with nice skin protection and moisturization properties. Its special thing is being an osmolyte, a molecule that helps to control cell-water balance. "
#                         target="_blank">Betaine</a>, <a href="https://incidecoder.com/ingredients/panthenol"
#                         title="Pro-Vitamin B5 is a goodie that moisturises the skin, has anti-inflammatory, skin protecting and wound healing properties. "
#                         target="_blank">Panthenol</a>, <a
#                         href="https://incidecoder.com/ingredients/saccharum-officinarum-extract"
#                         title="Also known as Sugarcane, Saccharum Officinarum is a handy moisturizing ingredient mostly used as a humectant..."
#                         target="_blank">Saccharum Officinarum (Sugar Cane) Extract</a>, <a
#                         href="https://incidecoder.com/ingredients/portulaca-oleracea-extract"
#                         title="Purslane Extract - a traditional Korean medicinal plant with skin-soothing, antioxidant and wound healing abilities. "
#                         target="_blank">Portulaca Oleracea Extract</a>, <a
#                         href="https://incidecoder.com/ingredients/butylene-glycol"
#                         title="An often used glycol that works as a solvent, humectant, penetration enhancer and also gives a good slip to the products. "
#                         target="_blank">Butylene Glycol</a></div><span style="display:block;"><small>Hover the mouse over
#                         an ingredient for short explanation. Read more on <a
#                             href="https://incidecoder.com/products/anua-heartleaf-77-soothing-toner"
#                             target="_blank">INCIDecoder</a>.</small></span>
#
#             </div>
#         </div>
#
#         <div class="skincare-gallery">
#             <a href="{{site.baseurl}}/skincare/routine">
#                 <img src="/student/images/glow-serum.jpg" alt="Skincare Routine" width="600" height="400">
#             </a>
#             <div class="skincare-desc">Beauty Of Joseon Glow Serum<div><a
#                         href="https://incidecoder.com/ingredients/propolis-extract"
#                         title="Sorry, no explanation for this one yet. :(" target="_blank">Propolis</a>, <a
#                         href="https://incidecoder.com/ingredients/niacinamide"
#                         title="A multi-functional skincare superstar that has clinically proven anti-aging, skin lightening, anti-inflammatory and barrier repair properties. "
#                         target="_blank">Niacinamide</a>, <a
#                         href="https://incidecoder.com/ingredients/calophyllum-tacamahaca-oil"
#                         title="Tamanu oil - a nourishing and moisturizing oil rich in fatty acids. Contains calophyllic acid that makes the oil extra healing and regenerating."
#                         target="_blank">Tamanu Oil</a>, <a href="https://incidecoder.com/ingredients/betaine-salicylate"
#                         title="The combination of famous exfoliant, salicylic acid and gentle moisturizer, betaine..."
#                         target="_blank">Betaine Salicylate (BHA)</a>, <a
#                         href="https://incidecoder.com/ingredients/melaleuca-alternifolia-leaf-extract"
#                         title="When it comes to Tea Tree, the essential oil is the one that steals the show with its well-documented antimicrobial and anti-acne effects..."
#                         target="_blank">Tea Tree Extract</a>, <a
#                         href="https://incidecoder.com/ingredients/lotus-corniculatus-seed-extract"
#                         title="Sorry, no explanation for this one yet. :(" target="_blank">Lotus Corniculatus Seed
#                         Extract</a></div><span style="display:block;"><small>Hover the mouse over an ingredient for
#                         short explanation. Read more on <a
#                             href="https://incidecoder.com/products/beauty-of-joseon-glow-serum-2"
#                             target="_blank">INCIDecoder</a>.</small></span>
#             </div>
#         </div>
#     </div>
#
#     <div style="clear: both"></div>
#     <div style="height: 400px">
#
#         <div class="skincare-gallery">
#             <img src="/student/images/skincare-specific-ingredients.jpg" alt="Skincare Products" width="600"
#                 height="400">
#             <div class="skincare-desc">Here are what specific ingredients do and what skin types they support.</div>
#         </div>
#
#         <div class="skincare-gallery">
#             <img src="/student/images/skincare-ingredient-mixer.jpg" alt="Skincare Ingredients" width="600"
#                 height="400">
#             <div class="skincare-desc">Mix and don't mix these ingredients together.
#             </div>
#         </div>
#
#         <div class="skincare-gallery">
#             <img src="/student/images/skincare-ingredient-combos.jpeg" alt="Skincare Routine" width="600" height="400">
#             <div class="skincare-desc">Combo these ingredients for even better results!</div>
#         </div>
#     </div>
#
#     <script src="/student/assets/js/skincare-ingredients.js"></script>
# </body>

# %%
<link rel="stylesheet" href="/student/assets/css/skincare-ingredients.css">

<body>
    <div>
        <!-- javascript will grabs these ids to create actions on click -->
        <p id="message">Click the button!</p>
        <button class="ingredient-button" id="ingredientSwitcher">Ingredient Switcher</button>
        <br>
        <br>
    </div>

    <div>
      <!-- links to switch -->
        <a target="blank" href="https://incidecoder.com/" class="ingredient-button" id="inci">INCIDecoder</a>
        <a target="blank" href="https://www.ewg.org/skindeep/" class="ingredient-button" id="ewg">EWG</a>
        <p></p>
    </div>

    <script >
    // variables to grab message, button, and 2 links
    const ingredientSwitcher = document.getElementById('ingredientSwitcher');
    const message = document.getElementById('message');
    const inciButton = document.getElementById('inci');
    const ewgButton = document.getElementById('ewg');
    
    // when button is clicked, switch the inner html and hrefs of anchor tags
    ingredientSwitcher.addEventListener('click', function () {
      // creae variables that grab href of anchor tags
      const inciHref = inciButton.getAttribute('href');
      const ewgHref = ewgButton.getAttribute('href');
      // console.log(inciHref, inciHref === 'https://incidecoder.com/');
      // if inci button has inci link, switch the innerhtml to opposite link and inner html
      // do the same with the ewg
      if (inciHref === 'https://incidecoder.com/') {
        inciButton.setAttribute('href', 'https://www.ewg.org/skindeep/');
        ewgButton.setAttribute('href', 'https://incidecoder.com/');
        inciButton.innerHTML = "EWG";
        ewgButton.innerHTML = "INCIDecoder";
        message.innerHTML = 'Switched!';
      } else {
        inciButton.setAttribute('href', 'https://incidecoder.com/');
        ewgButton.setAttribute('href', 'https://www.ewg.org/skindeep/');
        ewgButton.innerHTML = "EWG";
        inciButton.innerHTML = "INCIDecoder";
        message.innerHTML = 'Switched Back!';
    
    
      }
    });
    </script>
</body>
