# %% [markdown]
# ---
# title: Table of the Best Valorant Players
# toc: True
# comments: True
# description: HTML, CSS, and JavaScript in a table of my interests.
# courses: {'labnb': {'week': 3}}
# categories: ['C3.0', 'C3.1', 'C4.1']
# type: hacks
# ---

# %% [markdown]
# <!-- Head contains information to Support the Document -->
# <head>
#     <!-- load jQuery and DataTables output style and scripts -->
#     <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.4/css/jquery.dataTables.min.css">
#     <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
#     <script>var define = null;</script>
#     <script type="text/javascript" language="javascript" src="https://cdn.datatables.net/1.13.4/js/jquery.dataTables.min.js"></script>
# </head>
#
# <!-- Body contains the contents of the Document -->
# <body>
#
# <h1>Best Valorant Players By Most Played Character</h1>
#     <table id="demo" class="table">
#         <thead>
#             <tr>
#                 <th>Name</th>
#                 <th>Character</th>
#                 <th>Average Damage/Round</th>
#                 <th>Kills/Death Ratio</th>
#                 <th>FK</th>
#                 <th>FD</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Respect</td>
#                 <td>Omen</td>
#                 <td>178.8</td>
#                 <td>2.00</td>
#                 <td>3</td>
#                 <td>1</td>
#             </tr>
#             <tr>
#                 <td>Leo</td>
#                 <td>Sova</td>
#                 <td>155.6</td>
#                 <td>1.37</td>
#                 <td>114</td>
#                 <td>74</td>
#             </tr>
#             <tr>
#                 <td>Alfajer</td>
#                 <td>Killjoy</td>
#                 <td>157.7</td>
#                 <td>1.37</td>
#                 <td>243</td>
#                 <td>170</td>
#             </tr>
#             <tr>
#                 <td>Demon1</td>
#                 <td>Jett</td>
#                 <td>156.8</td>
#                 <td>1.19</td>
#                 <td>248</td>
#                 <td>204</td>
#             </tr>
#             <tr>
#                 <td>Runi</td>
#                 <td>Sova</td>
#                 <td>153.6</td>
#                 <td>1.20</td>
#                 <td>457</td>
#                 <td>281</td>
#             </tr>
#             <tr>
#                 <td>Clear</td>
#                 <td>Jett</td>
#                 <td>154.4</td>
#                 <td>1.27</td>
#                 <td>310</td>
#                 <td>244</td>
#             </tr>
#             <tr>
#                 <td>something</td>
#                 <td>Jett</td>
#                 <td>162.3</td>
#                 <td>1.34</td>
#                 <td>367</td>
#                 <td>280</td>
#             </tr>
#             <tr>
#                 <td>Jinggg</td>
#                 <td>Raze</td>
#                 <td>166.7</td>
#                 <td>1.23</td>
#                 <td>656</td>
#                 <td>492</td>
#             </tr>
#             <tr>
#                 <td>f0rsakeN</td>
#                 <td>Jett</td>
#                 <td>170.5</td>
#                 <td>1.33</td>
#                 <td>549</td>
#                 <td>379</td>
#             </tr>
#             <tr>
#                 <td>zekken</td>
#                 <td>Raze</td>
#                 <td>166.1</td>
#                 <td>1.24</td>
#                 <td>517</td>
#                 <td>399</td>
#             </tr>
#             <tr>
#                 <td>Asuna</td>
#                 <td>Raze</td>
#                 <td>169.9</td>
#                 <td>1.10</td>
#                 <td>479</td>
#                 <td>378</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
#
# <!-- Script is used to embed executable code -->
# <script>
#    $("#demo").DataTable();
# </script>
#
#
#
# ## Hacks
# This lesson teaches you about tables.  In this hack, it is important that you analze the difference in the styles of output shown.
# - Make your own tables, with data according to your interests.
# - Describe a benefit of a markdown table.
# - Try to Style the HTML table using w3schools.
# - Describe the difference between HTML and JavaScript.
# - Describe a benefit of a table that uses JavaScript.
