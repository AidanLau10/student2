# %% [markdown]
# ---
# title: Freeform
# comments: true
# hide: true
# layout: post
# description: My freeform picture
# courses: { labnb: {week: 0} }
# type: hacks
# ---

# %% [markdown]
# ![Freeform Picture](/student/images/freeform.jpg)
